# %%
print("Hello")
# Out:
# Hello

# %%
print('Pooja Singh')
# Out:
# Pooja Singh

# %%
x=10
y='Hello'
print(x)
print(y)
# Out:
# 10
# Hello

# %%
print(x,y)
# Out:
# 10 Hello

# %%
#The value of x is 10
print('The value of x and y is', x,y)
# Out:
# The value of x and y is 10 Hello
